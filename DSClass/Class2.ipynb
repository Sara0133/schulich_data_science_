# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/delinai/schulich_ds1/main/Datasets/kc_house_data.csv')

# %%
# what are the categories of homes that we have
# how can we classify them (family, luxury rural)
# what conditions would we use to classify the homes 
# ie. Spread sqft, spread of bedrooms/bathrooms, floors, etc

# %%
df.(info)
# Out:
#   Cell In[2], line 1
#     df.(info)
#        ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
#MY NOTES FOR HER QUESTIONS --- CLASSIFYING HOME 
# if bedroom less than 1 "studio"
#if bedroom between 1-5 if lot >0 family home 
            #if sqft > 2500 large home 
            #if sqft < 2500 large home 
# if bedroom between 1-5 if lot =0 appartment 
# if bedroom 5+ luxury home 
#

# %%
# HER NOTRDS FOR QUESTION
# bedrooms 
# grade material

# %%
sns.boxplot(x='bedrooms', y='price', data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
# avg home 2-4 bedroom

# %%
# start by number of bedroom 
# between 2-4 standard >4 large home <2 small

# %%
sns.boxplot(x='grade', y='price', data=df)
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
# grade >9 luxury 6-8 standard <6 low grade

# %%
sns.scatterplot(x='sqft_living', y='sqft_lot', data=df)
# Out:
# <Axes: xlabel='sqft_living', ylabel='sqft_lot'>

# %%
df['df_lot_to_living_ratio'] =df['sqft_lot'] / df['sqft_living']

# %%
# use common snese if sqft living to sqft lot size > 50 rural/large else is normal

# %%
# if anything renovated or built after 2000 otherwise old

# %%
#price per square foot

# %%
df['price_per_sqft'] = df['price'] / df['sqft_living']

# %%
sns.boxplot(y='price_per_sqft', data=df)
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df.groupby('zipcode')['price_per_sqft'].mean()
# Out:
# zipcode
# 98001    151.387938
# 98002    151.174091
# 98003    157.113414
# 98004    475.435611
# 98005    314.929231
#             ...
# 98177    292.918745
# 98178    189.172528
# 98188    169.007306
# 98198    178.428610
# 98199    376.546345
# Name: price_per_sqft, Length: 70, dtype: float64

# %%
#avg price per sqft by zipcode

# %%
price_per_sqft = df.groupby('zipcode')['price_per_sqft'].mean().to_dict()

# %%
df['avg_price_per_sqft'] = df['zipcode'].map(price_per_sqft)

# %%
sns.boxplot(x='zipcode',y='price_per_sqft',data=df)
# Out:
# <Axes: xlabel='zipcode', ylabel='price_per_sqft'>

# %%
#see alot of difference in zipcode in price per sqft

# %%
# each home has hundreds of home per zipcode so you grpup by zipcode then see what u want to see from data

# %%
df.groupby('zipcode')['price'].sum()
# Out:
# zipcode
# 98001    101651298.0
# 98002     46622523.0
# 98003     82351158.0
# 98004    429828885.0
# 98005    136107699.0
#             ...
# 98177    172427275.0
# 98178     81380542.0
# 98188     39314655.0
# 98198     84806087.0
# 98199    251007196.0
# Name: price, Length: 70, dtype: float64

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,10))
sns.boxplot(x='zipcode',y='price_per_sqft',data=df[df['waterfront']==1], ax=ax1)
sns.boxplot(x='zipcode',y='price_per_sqft',data=df[df['waterfront']==0], ax=ax2)
# Out:
# <Axes: xlabel='zipcode', ylabel='price_per_sqft'>

# %%
#share why to compare apple to apple

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(20,10), sharey=True)
sns.boxplot(x='zipcode',y='price_per_sqft',data=df[df['waterfront']==1], ax=ax1)
sns.boxplot(x='zipcode',y='price_per_sqft',data=df[df['waterfront']==0], ax=ax2)
# Out:
# <Axes: xlabel='zipcode', ylabel='price_per_sqft'>

# %%
# can use map function to map average price to each vale in the clolumd    ---- like doing v lookup in excel

# %%
price_per_sqft_frame = df.groupby('zipcode')['price_per_sqft'].mean().to_frame()

# %%
new_df = pd.merge(df, price_per_sqft_frame, left_on = 'zipcode', right_on='zipcode')

# %%
new_df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      4060000240  20140623T000000   205425.0         2       1.00
# 2      4058801670  20140717T000000   445000.0         3       2.25
# 3      2976800796  20140925T000000   236000.0         3       1.00
# 4      6874200960  20150227T000000   170000.0         2       1.00
# ...           ...              ...        ...       ...        ...
# 21608  2525049086  20141003T000000  2720000.0         4       3.25
# 21609  2525049113  20140725T000000  1950000.0         4       3.50
# 21610  3262300485  20150421T000000  2250000.0         5       5.25
# 21611  6447300365  20141113T000000  2900000.0         5       4.00
# 21612  3262300818  20150227T000000  1865000.0         4       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_built  \
# 0             1180      5650     1.0           0     0  ...      1955
# ...

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_renovated  \
# 0             1180      5650     1.0           0     0  ...             0
# ...

# %%
# is the price above / below the average for the zipcode
df['above/below'] = df['price_per_sqft'] - df['avg_price_per_sqft']

# %%
## refine ur definition

# %%
df['avg_sqft_for_area'] = df['zipcode'].map(df.groupby('zipcode')['sqft_living'].mean().to_dict())

# %%
df['above/below_sqft'] = df['sqft_living'] - df['avg_sqft_for_area']

# %%
def sale_category(row):
    # condition 1: if the house sold for less per sqft than the average price for the zipcode, AND the house was bigger than the avg size for the zipcode, then we got a value purchase
    if row["above/below"] < 0 and row['above/below_sqft'] > 0:
        return "value sale"
    # condition 2: if the house sold for less per sqft than the avg price for the zipcode, OR the house was bigger than avg for the area, then not necessarily a deal, but good outcome
    elif row["above/below"] < 0 or row['above/below_sqft'] > 0:
        return "avegare sale"
    # if neither was met, house is overpriced
    else:
        return "overpriced"

# %%
df['sale_value'] = df.apply(sale_category, axis=1)

# %%
df['sale_value'] = df.apply(sale_category, axis=1)

# %%
df.groupby('sale_value').count()
# Out:
#                 id  date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# sale_value
# avegare sale  7774  7774   7774      7774       7774         7774      7774
# overpriced    6866  6866   6866      6866       6866         6866      6866
# value sale    6973  6973   6973      6973       6973         6973      6973
#
#               floors  waterfront  view  ...   lat  long  sqft_living15  \
# sale_value                              ...
# avegare sale    7774        7774  7774  ...  7774  7774           7774
# overpriced      6866        6866  6866  ...  6866  6866           6866
# value sale      6973        6973  6973  ...  6973  6973           6973
#
#               sqft_lot15  df_lot_to_living_ratio  price_per_sqft  \
# sale_value
# avegare sale        7774                    7774            7774
# overpriced          6866                    6866            6866
# value sale          6973                    6973            6973
#
# ...

# %%
#WHAT WE COVERED 
# feature engeneering : map(), apply () both used to define custom categories
# coloumn operations 
#winsorization/outliers 
#univariate anaysis with boxplot 
#bivatiate anaysis with correlation coff or scatter matrix 
#OUTSTANDING EXAMPLE TO COVER 
#dealing with missing values

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/delinai/schulich_ds1_2024/main/Datasets/class2_sample_dataset.csv')

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/delinai/schulich_ds1_2024/main/Datasets/class2_sample_dataset.csv')

# %%
df2
# Out:
#      id   age         salary           city  experience  department
# 0     1  56.0   21864.850000        Nw York          33  Operations
# 1     2  69.0   29498.270000        Chicago           5     Finance
# 2     3  46.0   59544.580000        Chicago          19  Operations
# 3     4  32.0            NaN  San Francisco           4          IT
# 4     5  60.0   57140.640000  San Francisco          35          HR
# ..  ...   ...            ...            ...         ...         ...
# 95   96  42.0   50984.740000    Los Angeles          39     Finance
# 96   97  62.0  255192.192222       New York           5     Finance
# 97   98  58.0   63099.750000  San Francisco          22     Finance
# 98   99  46.0   53084.750000        Chicago          29     Finance
# 99  100  32.0   28347.750000  San Francisco           3          IT
#
# [100 rows x 6 columns]

# %%
# why is the data missing 
    #MCAR= data missing completely at random MAR= data missing at random  MNAR= Data missing not at random 
#matters if data missing randomly or not because it could be legitimate ie missing cuz its option for data point or it could determin how we deal with it
#dont want to add bias witthin data set if we dont fill in missing data completely correct can make data that not there 
#MAR= there is a pattern to missing data 
#MCAR = not picking particular segment that might be more or less likely not to answer no matter how u deal with data u wont really matter

# %%
# easy way u tell if u have black space or problem if u see object or something and u expect numbers it probably an issue

# %%
#MNAR= may not need to be filled in at all supposed to not be there

# %%
# if 10% of totla data is missing you can drop it not drop coloms wiht missing data just data

# %%
df2[df2.city.isnull()]['salary'].mean()
# Out:
# 47403.23714285714

# %%
df2.groupby('city')['salary'].mean()
# Out:
# city
# Chicago          58053.367346
# Los Angeles      75837.098963
# New York         70744.525222
# Nw York          52600.087778
# San Francisco    56301.341304
# Name: salary, dtype: float64

# %%
df2[df2.salary.isnull()]
# Out:
#     id   age  salary           city  experience  department
# 3    4  32.0     NaN  San Francisco           4          IT
# 6    7  38.0     NaN            NaN          28          HR
# 33  34  45.0     NaN  San Francisco          26     Finance
# 41  42  54.0     NaN  San Francisco          25          IT
# 42  43  68.0     NaN            NaN          24     Finance
# 50  51   NaN     NaN        Nw York          14  Operations
# 68  69  21.0     NaN  San Francisco           5          IT
# 81  82  48.0     NaN        Chicago          28  Operations

# %%
df2.groupby(['department','city']).salary.mean()
# Out:
# department  city
# Finance     Chicago           40789.412500
#             Los Angeles       54512.467143
#             New York         121761.555741
#             Nw York           51372.045000
#             San Francisco     62636.118333
# HR          Chicago           39700.273333
#             Los Angeles      147600.641111
#             New York          54351.024000
#             Nw York           62097.882500
#             San Francisco     55884.838571
# IT          Chicago           51376.870000
#             Los Angeles       39039.673333
#             New York          52566.865000
#             Nw York           63090.580000
#             San Francisco     51687.445000
# Operations  Chicago           76071.441528
#             Los Angeles      114549.637407
#             New York          43918.902857
#             Nw York           29587.295000
#             San Francisco     53528.415000
# Name: salary, dtype: float64

# %%
# % of missing data per column
df2.isnull().sum()/100
# Out:
# id            0.00
# age           0.10
# salary        0.08
# city          0.09
# experience    0.00
# department    0.00
# dtype: float64

# %%
df2.isnull().sum().sum() / df2.size
# Out:
# 0.045

# %%
#missing data is less than 10% so can just drop those rows 
#generally should do full anaysis of missing data u may still want to fill them in to not drop data 
#if ur dealing with million rows may be easier to drop 
#understand why data is missing and how we can better collect it ie. in phone game women are higher spenders but if they dont put gender down u missing out on large set

# %%
df2.isnull().sum().sum() / df2.drop('id', axis=1).size
# Out:
# 0.054

# %%
#compare before and after when dropping data

# %%
df2.describe(include='all')
# Out:
#                 id        age         salary           city  experience  \
# count   100.000000  90.000000      92.000000             91  100.000000
# unique         NaN        NaN            NaN              5         NaN
# top            NaN        NaN            NaN  San Francisco         NaN
# freq           NaN        NaN            NaN             27         NaN
# mean     50.500000  44.111111   61930.020664            NaN   21.220000
# std      29.011492  15.169043   49068.536745            NaN   11.350771
# min       1.000000  19.000000   20901.330000            NaN    1.000000
# 25%      25.750000  32.000000   38496.567500            NaN   12.750000
# 50%      50.500000  42.500000   51621.040000            NaN   23.000000
# 75%      75.250000  57.750000   63346.867500            NaN   31.000000
# max     100.000000  69.000000  255192.192222            NaN   39.000000
#
#        department
# count         100
# unique          4
# top       Finance
# freq           29
# ...

# %%
#example of dropping data points 
df2.dropna().describe(include='all')
# Out:
#                 id        age         salary           city  experience  \
# count    76.000000  76.000000      76.000000             76   76.000000
# unique         NaN        NaN            NaN              5         NaN
# top            NaN        NaN            NaN  San Francisco         NaN
# freq           NaN        NaN            NaN             21         NaN
# mean     53.144737  44.723684   63919.643436            NaN   22.039474
# std      28.928281  15.785731   53220.816385            NaN   11.278819
# min       1.000000  19.000000   20901.330000            NaN    1.000000
# 25%      28.750000  31.750000   39036.797500            NaN   14.500000
# 50%      56.500000  44.000000   50703.115000            NaN   23.000000
# 75%      76.250000  59.250000   63517.910000            NaN   32.000000
# max     100.000000  69.000000  255192.192222            NaN   39.000000
#
#         department
# count           76
# unique           4
# top     Operations
# freq            23
# ...

# %%
#when apply treatment to missing data compare before and after to make sure dont make bias

# %%
#filling in with constant value 
#certain variables that u should never put in (protected class)-- really personal things thier identity

# %%
# filling in with constant value
df2['city'] = df2['city'].fillna('Unknown')

# %%
df2.groupby('city').count(
    
)
# Out:
#                id  age  salary  experience  department
# city
# Chicago        19   16      18          19          19
# Los Angeles    15   13      15          15          15
# New York       20   19      20          20          20
# Nw York        10    8       9          10          10
# San Francisco  27   25      23          27          27
# Unknown         9    9       7           9           9

# %%
#could also use custom function if we can define a model

# %%
#age-missing completely at random 
#fill missing data with median of data 
# if there is no pattern associated with missing values can just replace with mean of coloumn

# %%
df2['age'] = df2['age'].fillna(df2['age'].median())

# %%
#salary- missing at random and varies by city 
#may want to do it by city 
#transform function will transform and replace with the average for that thing 
    #only want to replace NAN so put transform function in fillna to transform only NAN by city

# %%
df2['city'] = df2['city'].replace('Nw York', 'New York')

# %%
df2.groupby('city').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df2.groupby('city').count()
#
# NameError: name 'df2' is not defined
